# %%
import pandas as pd
import numpy as np

# %%
assets = ["ETH", "ETC", "XMR"]
datetime = pd.date_range(start="22/06/2017", end="22/06/2018", freq="15min")

# %%
datetime
# Out:
# DatetimeIndex(['2017-06-22 00:00:00', '2017-06-22 00:15:00',
#                '2017-06-22 00:30:00', '2017-06-22 00:45:00',
#                '2017-06-22 01:00:00', '2017-06-22 01:15:00',
#                '2017-06-22 01:30:00', '2017-06-22 01:45:00',
#                '2017-06-22 02:00:00', '2017-06-22 02:15:00',
#                ...
#                '2018-06-21 21:45:00', '2018-06-21 22:00:00',
#                '2018-06-21 22:15:00', '2018-06-21 22:30:00',
#                '2018-06-21 22:45:00', '2018-06-21 23:00:00',
#                '2018-06-21 23:15:00', '2018-06-21 23:30:00',
#                '2018-06-21 23:45:00', '2018-06-22 00:00:00'],
#               dtype='datetime64[ns]', length=35041, freq='15T')

# %%
df = pd.DataFrame(np.random.randn(len(datetime), len(assets)), index=datetime, columns=assets)

# %%
df
# Out:
#                           ETH       ETC       XMR
# 2017-06-22 00:00:00  0.896046 -0.816917  0.565745
# 2017-06-22 00:15:00  0.355707  1.576618 -1.787323
# 2017-06-22 00:30:00  1.527317  0.168057 -0.099564
# 2017-06-22 00:45:00  1.633548  1.043444  0.609900
# 2017-06-22 01:00:00  0.182967 -0.308039  0.416014
# 2017-06-22 01:15:00  1.181989  2.197034  0.206457
# 2017-06-22 01:30:00 -1.352627 -0.584720 -0.675191
# 2017-06-22 01:45:00  1.761852  1.406446 -0.405480
# 2017-06-22 02:00:00 -1.210586 -0.076903  2.583587
# 2017-06-22 02:15:00 -1.072548  0.153347  0.296145
# 2017-06-22 02:30:00  0.728711  1.459591  2.033972
# 2017-06-22 02:45:00  0.014966 -0.907062 -0.050382
# 2017-06-22 03:00:00 -0.152256 -0.364334  0.028691
# 2017-06-22 03:15:00  1.945098 -0.790111 -1.204136
# 2017-06-22 03:30:00 -1.516911 -1.147845 -0.394854
# 2017-06-22 03:45:00 -0.505622  1.097821  1.258743
# 2017-06-22 04:00:00 -1.866289  0.549914 -1.137383
# 2017-06-22 04:15:00  1.891413  0.337806  0.910263
# ...
